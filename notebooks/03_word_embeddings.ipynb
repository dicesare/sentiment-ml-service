# %% [markdown]
# # 03 — Word embeddings
# Design notes for comparing learned Word2Vec/FastText representations with sparse TF-IDF features.

# %%
from gensim.models import Word2Vec

# tokenized_train contains tokens from the training split only.
# embedding = Word2Vec(tokenized_train, vector_size=100, window=5, min_count=2, seed=42)

# %% [markdown]
# ## Questions answered
# Measure out-of-vocabulary rate, inspect nearest neighbours, compare mean-vector and sequence representations, and record the added training/inference cost.
