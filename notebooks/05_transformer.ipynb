# %% [markdown]
# # 05 — Transformer transfer learning
# A BERT-style candidate tests the value of contextual representations against classical and recurrent baselines.

# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer

MODEL_ID = 'distilbert-base-uncased'
tokenizer = AutoTokenizer.from_pretrained(MODEL_ID)
model = AutoModelForSequenceClassification.from_pretrained(MODEL_ID, num_labels=2)

# %% [markdown]
# ## Selection criteria
# Track macro F1, minority recall, calibration, CPU latency, memory and artifact size. A higher score does not automatically justify a much heavier production model.
