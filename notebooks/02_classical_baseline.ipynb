# %% [markdown]
# # 02 — Classical sentiment baseline
# A transparent TF-IDF + logistic-regression baseline establishes the performance and latency floor.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

baseline = Pipeline([
    ('tfidf', TfidfVectorizer(ngram_range=(1, 2), min_df=3)),
    ('model', LogisticRegression(max_iter=1000, class_weight='balanced'))
])

# %% [markdown]
# ## Evaluation
# Report macro F1 and per-class recall alongside ROC-AUC. Inspect errors involving negation, sarcasm, spelling and domain-specific vocabulary.
